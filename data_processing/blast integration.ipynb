# %%
from qiime2 import Artifact
import pandas as pd
from Bio.Blast import NCBIWWW, NCBIXML
import time

# %%
rep_seqs_qza = Artifact.load('qiime2_blast_data/SRA1038019-rep_seqs.qza') 
taxonomy_qza = Artifact.load('qiime2_blast_data/SRA1038019-taxonomy.qza')

rep_seqs = rep_seqs_qza.view(pd.Series).to_frame(name='Sequence')
rep_seqs.index.name = 'Feature ID'
tax = taxonomy_qza.view(pd.Series)
tax.index.name = 'Feature ID' 

merged = pd.merge(rep_seqs, tax, left_index=True, right_index=True)
merged.reset_index(inplace=True)
unassigned = merged[merged['Taxon'].str.endswith('s__')]
unique_values_count = unassigned.iloc[:, 0].nunique()
unassigned
# Out:
#                           Feature ID  \
# 3   4900b14ef37cec718bf18a0d92210a03
# 4   d1438cbf44c49ecae37c506c03115689
# 5   d346c8a02aff2fa769c2e94e95447488
# 11  29841a48cdb3345f69e10a0bbb13f91f
# 12  7f6d5a06aee44bcfc8e166fa2a8ed03d
# 13  ca349b86996171347f6b5afb7b9b5e6c
# 14  bc2eec26f20121d03c3ff6790b97fcbb
# 18  faef44dd4e01f7c4519a0b3a8979e6ad
# 20  72909c55c824fa230fa38e17d57ff46e
# 21  cec58968560141b8c1f19ff3cd3dbc32
# 22  e80dd587b56f01005f1449880db7c024
# 23  c0daf916a4fca792dbd956ba1377b536
# 25  e7ee63fee0af657e48429aacc96113bd
# 26  12fe9bc4b3c216f4b6bb7163e226582b
# 28  d6588d9cc8688d706ce164d37a89c2c7
# 30  5c7eee06342c71e0c3119eebdf1fa0d4
# 32  8efb26fcf4cd6c6fc0ee2e581eaedf2e
# 34  8826dffa3e49fc78e4d235b5cbf995ab
# 36  1f6adeb643bf0bf9ff5770df8c8a58b9
# 37  136797f7a299de78fb2c0dac4dc756c5
# 39  4a2738a8f5e31068f68a08ec167589d6
# 40  3862cdba0e52f6b9e73fb73aabcee8fc
# 42  77c0ee7d06bf3015aaf5b3dbb4e5cf47
# 44  39dfd641e980997eb09e0fbfa32515bc
# 48  8bfb7db560fbb32ad2911b65634a5c6f
# 49  10ef72bab177aa520342b617f1ee2186
# 50  51b367f222f3c99e8170666c53928e1d
# 51  2ee4deff7b5c7d3798c0cae18d13632a
# 52  95fcb2d33bd2a46e98e51e5cb5e4d924
# 53  9186e853f994fd8285d68ccd223cd34d
#
#                                              Sequence  \
# 3   (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((A...
# 4   (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((A...
# 5   (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((C...
# 11  (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((A...
# 12  (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((A...
# 13  (((C)), ((C)), ((T)), ((A)), ((C)), ((G)), ((G...
# 14  (((C)), ((C)), ((T)), ((A)), ((C)), ((G)), ((G...
# 18  (((C)), ((C)), ((T)), ((A)), ((C)), ((G)), ((G...
# 20  (((C)), ((C)), ((T)), ((A)), ((C)), ((G)), ((G...
# 21  (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((A...
# 22  (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((T...
# 23  (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((T...
# 25  (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((C...
# 26  (((C)), ((C)), ((T)), ((A)), ((C)), ((G)), ((G...
# 28  (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((T...
# 30  (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((C...
# 32  (((C)), ((C)), ((T)), ((A)), ((C)), ((G)), ((G...
# 34  (((T)), ((C)), ((T)), ((A)), ((C)), ((G)), ((G...
# 36  (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((T...
# 37  (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((C...
# 39  (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((C...
# 40  (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((C...
# 42  (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((A...
# 44  (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((C...
# 48  (((C)), ((C)), ((T)), ((A)), ((C)), ((G)), ((G...
# 49  (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((C...
# 50  (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((A...
# 51  (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((A...
# 52  (((C)), ((C)), ((T)), ((A)), ((C)), ((G)), ((G...
# 53  (((G)), ((A)), ((C)), ((T)), ((A)), ((C)), ((A...
#
#                                                 Taxon
# 3   k__Bacteria; p__Bacteroidetes; c__Bacteroidia;...
# 4   k__Bacteria; p__Firmicutes; c__Clostridia; o__...
# 5   k__Bacteria; p__Firmicutes; c__Clostridia; o__...
# 11  k__Bacteria; p__Firmicutes; c__Clostridia; o__...
# 12  k__Bacteria; p__Firmicutes; c__Clostridia; o__...
# 13       k__Bacteria; p__OD1; c__; o__; f__; g__; s__
# 14       k__Bacteria; p__OD1; c__; o__; f__; g__; s__
# 18       k__Bacteria; p__OD1; c__; o__; f__; g__; s__
# 20       k__Bacteria; p__OD1; c__; o__; f__; g__; s__
# 21  k__Bacteria; p__Firmicutes; c__Clostridia; o__...
# 22  k__Bacteria; p__Proteobacteria; c__Gammaproteo...
# 23  k__Bacteria; p__Firmicutes; c__Clostridia; o__...
# 25  k__Bacteria; p__Bacteroidetes; c__Bacteroidia;...
# 26       k__Bacteria; p__OD1; c__; o__; f__; g__; s__
# 28  k__Bacteria; p__Proteobacteria; c__Gammaproteo...
# 30  k__Bacteria; p__Firmicutes; c__Clostridia; o__...
# 32       k__Bacteria; p__OD1; c__; o__; f__; g__; s__
# 34       k__Bacteria; p__OD1; c__; o__; f__; g__; s__
# 36  k__Bacteria; p__Bacteroidetes; c__Bacteroidia;...
# 37  k__Bacteria; p__Bacteroidetes; c__Bacteroidia;...
# 39  k__Bacteria; p__Proteobacteria; c__Epsilonprot...
# 40  k__Bacteria; p__Firmicutes; c__Clostridia; o__...
# 42  k__Bacteria; p__Firmicutes; c__Clostridia; o__...
# 44  k__Bacteria; p__Firmicutes; c__Clostridia; o__...
# 48       k__Bacteria; p__OD1; c__; o__; f__; g__; s__
# 49  k__Bacteria; p__Firmicutes; c__Clostridia; o__...
# 50  k__Bacteria; p__Firmicutes; c__Clostridia; o__...
# 51  k__Bacteria; p__Firmicutes; c__Clostridia; o__...
# 52       k__Bacteria; p__OD1; c__; o__; f__; g__; s__
# 53  k__Bacteria; p__Firmicutes; c__Clostridia; o__...

# %%
def blast_classifier(rep_seqs_path, taxonomy_path, top_n=10):
    '''
    This classifier classifies the sequences by performing BLAST search on the unassigned sequences.
    
    Parameters:
    rep_seqs_path (str): path to the representative sequences file
    taxonomy_path (str): path to the taxonomy file
    top_n (int): number of top alignments to consider each BLAST search
     max_results (int): number of unassigned sequences to process
      
    Returns:
    pd.DataFrame: DataFrame containing BLAST results.  
    '''
    # load in files
    rep_seqs_qza = Artifact.load(rep_seqs_path) 
    taxonomy_qza = Artifact.load(taxonomy_path)

    # convert taxonomy to df
    taxonomy_df = taxonomy_qza.view(pd.DataFrame)

    # convert req seqs to df
    rep_seqs = rep_seqs_qza.view(pd.Series).to_frame(name='Sequence')
    rep_seqs.index.name = 'Feature ID'

    # merge dfs on Feature ID
    merged = pd.merge(rep_seqs, taxonomy_df, left_index=True, right_index=True)
    merged.reset_index(inplace=True)

    # filter for entries without species assignment
    unassigned = merged[merged['Taxon'].str.endswith('s__')]

    # empty list for BLAST results
    blast_results = []

    # perform BLAST for each unassigned sequencec
    for feature_id, row in unassigned.iterrows():
        sequence = row['Sequence']
        
        # BLAST search
        result_handle = NCBIWWW.qblast('blastn', 'nt', sequence)
        blast_record = NCBIXML.read(result_handle)
        if blast_record.alignments:
            for alignment in blast_record.alignments[:top_n]:
                for hsp in alignment.hsps:
                    #taxonomy = row['Taxon']
                    blast_results.append({
                        'Feature ID': feature_id,
                        'expect': hsp.expect,
                        'score': hsp.score,
                        'bits': hsp.bits, 
                        'align_length': hsp.align_length,
                        'identities': hsp.identities, 
                        'positives': hsp.positives,
                        'gaps': hsp.gaps,
                        'query': hsp.query,
                        'sbjct': hsp.sbjct,
                        'match': hsp.match,
                        #'taxonomy': taxonomy  
                    })
                time.sleep(1)

    blast_results_df = pd.DataFrame(blast_results)

    return blast_results_df

# file paths
rep_seqs_path = 'qiime2_blast_data/SRA1038019-rep_seqs.qza'
taxonomy_path = 'qiime2_blast_data/SRA1038019-taxonomy.qza'

# Load the taxonomy artifact
#taxonomy_qza_path = 'qiime2_blast_data/ERA1115542-taxonomy.qza'
#taxonomy_qza = Artifact.load(taxonomy_qza_path)

# Convert the taxonomy artifact to a DataFrame
#taxonomy_df = taxonomy_qza.view(pd.DataFrame)

# Display the first few rows of the taxonomy DataFrame
#taxonomy_df.head()

# Display the first few rows of the taxonomy DataFrame
#print(taxonomy_df.head())

# Save the DataFrame to a CSV file for further inspection if needed
#taxonomy_df.to_csv('taxonomy.csv', index=False)

# Perform BLAST classification and get results
results_df = blast_classifier(rep_seqs_path, taxonomy_path) 

# Display the results
results_df

# %%
#test

# %%
def get_blast_taxonomy(sequence, expect_threshold=0.001):
    result_handle = NCBIWWW.qblast('blastn', 'nt', sequence)
    blast_record = NCBIXML.read(result_handle)
    for alignment in blast_record.alignments:
        for hsp in alignment.hsps:
            if hsp.expect < expect_threshold:
                taxonomy = f"k__{alignment.hit_def.split(';')[0]}; p__{alignment.hit_def.split(';')[1]}; " \
                           f"c__{alignment.hit_def.split(';')[2]}; o__{alignment.hit_def.split(';')[3]}; " \
                           f"f__{alignment.hit_def.split(';')[4]}; g__{alignment.hit_def.split(';')[5]}; " \
                           f"s__{alignment.hit_def.split(';')[6]}"
                return taxonomy
    return None

# perform BLAST for each sequence and create reference database files
otu_list = []
taxonomy_list = []

for feature_id, sequence in rep_seqs.items():
    taxonomy = get_blast_taxonomy(sequence)
    if taxonomy:
        otu_list.append(feature_id)
        taxonomy_list.append(taxonomy)

# df for OTUs and Taxonomy
otu_df = pd.DataFrame({'Feature ID': otu_list, 'Taxonomy': taxonomy_list})
otu_artifact = Artifact.import_data('FeatureData[Sequence]', otu_df)
taxonomy_artifact = Artifact.import_data('FeatureData[Taxonomy]', otu_df)

# save artifacts
otu_artifact.save('otus.qza')
taxonomy_artifact.save('taxonomy.qza')

# %%
#naive bayes
# import necessary plugins
qiime tools import \
  --type 'FeatureData[Sequence]' \
  --input-path otus.qza \
  --output-path ref-seqs.qza

qiime tools import \
  --type 'FeatureData[Taxonomy]' \
  --input-path taxonomy.qza \
  --output-path ref-taxonomy.qza

# Train the classifier
qiime feature-classifier fit-classifier-naive-bayes \
  --i-reference-reads ref-seqs.qza \
  --i-reference-taxonomy ref-taxonomy.qza \
  --o-classifier classifier.qza
